# %%
import pickle
import numpy as np
import seaborn as sns
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils import to_categorical
from keras.layers import Dropout
from keras.optimizers import Adam
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix

# %%
path = "/kaggle/input/dataset-chest/"

# %%
df_chest_filt = pd.read_pickle((path + "combined_chest_filtered.pkl"))

# %%
df_chest_filt.head()
# Out:
#          id   ACC_x   ACC_y   ACC_z       ECG       EMG       EDA       TEMP  \
# 214583  2.0  0.8914 -0.1102 -0.2576  0.030945 -0.003708  5.710983  29.083618
# 214584  2.0  0.8926 -0.1086 -0.2544  0.033646 -0.014145  5.719376  29.122437
# 214585  2.0  0.8930 -0.1094 -0.2580  0.033005  0.010208  5.706406  29.115234
# 214586  2.0  0.8934 -0.1082 -0.2538  0.031815  0.012634  5.712509  29.126709
# 214587  2.0  0.8930 -0.1096 -0.2570  0.030350  0.002060  5.727005  29.100861
#
#             RESP  label
# 214583  1.191711    1.0
# 214584  1.139832    1.0
# 214585  1.141357    1.0
# 214586  1.155090    1.0
# 214587  1.133728    1.0

# %%
df_chest_filt.isnull().sum()
# Out:
# id       0
# ACC_x    0
# ACC_y    0
# ACC_z    0
# ECG      0
# EMG      0
# EDA      0
# TEMP     0
# RESP     0
# label    0
# dtype: int64

# %%
df_chest_filt.isna().any()
# Out:
# id       False
# ACC_x    False
# ACC_y    False
# ACC_z    False
# ECG      False
# EMG      False
# EDA      False
# TEMP     False
# RESP     False
# label    False
# dtype: bool

# %%
df_chest_filt.groupby(['id', 'label']).count()
# Out:
#              ACC_x   ACC_y   ACC_z     ECG     EMG     EDA    TEMP    RESP
# id   label
# 2.0  1.0    800800  800800  800800  800800  800800  800800  800800  800800
#      2.0    430500  430500  430500  430500  430500  430500  430500  430500
#      3.0    253400  253400  253400  253400  253400  253400  253400  253400
# 3.0  1.0    798000  798000  798000  798000  798000  798000  798000  798000
#      2.0    447917  447917  447917  447917  447917  447917  447917  447917
#      3.0    262500  262500  262500  262500  262500  262500  262500  262500
# 4.0  1.0    810601  810601  810601  810601  810601  810601  810601  810601
#      2.0    444500  444500  444500  444500  444500  444500  444500  444500
#      3.0    260400  260400  260400  260400  260400  260400  260400  260400
# 5.0  1.0    838600  838600  838600  838600  838600  838600  838600  838600
#      2.0    451500  451500  451500  451500  451500  451500  451500  451500
#      3.0    261800  261800  261800  261800  261800  261800  261800  261800
# 6.0  1.0    826000  826000  826000  826000  826000  826000  826000  826000
#      2.0    455000  455000  455000  455000  455000  455000  455000  455000
#      3.0    260400  260400  260400  260400  260400  260400  260400  260400
# 7.0  1.0    830200  830200  830200  830200  830200  830200  830200  830200
#      2.0    448000  448000  448000  448000  448000  448000  448000  448000
#      3.0    260401  260401  260401  260401  260401  260401  260401  260401
# 8.0  1.0    818300  818300  818300  818300  818300  818300  818300  818300
#      2.0    469000  469000  469000  469000  469000  469000  469000  469000
#      3.0    258999  258999  258999  258999  258999  258999  258999  258999
# 9.0  1.0    826000  826000  826000  826000  826000  826000  826000  826000
#      2.0    451500  451500  451500  451500  451500  451500  451500  451500
#      3.0    260400  260400  260400  260400  260400  260400  260400  260400
# 10.0 1.0    826000  826000  826000  826000  826000  826000  826000  826000
#      2.0    507500  507500  507500  507500  507500  507500  507500  507500
#      3.0    260400  260400  260400  260400  260400  260400  260400  260400
# 11.0 1.0    826000  826000  826000  826000  826000  826000  826000  826000
#      2.0    476000  476000  476000  476000  476000  476000  476000  476000
#      3.0    257600  257600  257600  257600  257600  257600  257600  257600
# 13.0 1.0    826001  826001  826001  826001  826001  826001  826001  826001
#      2.0    464800  464800  464800  464800  464800  464800  464800  464800
#      3.0    267400  267400  267400  267400  267400  267400  267400  267400
# 14.0 1.0    826000  826000  826000  826000  826000  826000  826000  826000
#      2.0    472500  472500  472500  472500  472500  472500  472500  472500
#      3.0    260401  260401  260401  260401  260401  260401  260401  260401
# 15.0 1.0    822500  822500  822500  822500  822500  822500  822500  822500
#      2.0    480200  480200  480200  480200  480200  480200  480200  480200
#      3.0    260400  260400  260400  260400  260400  260400  260400  260400
# 16.0 1.0    826000  826000  826000  826000  826000  826000  826000  826000
#      2.0    471101  471101  471101  471101  471101  471101  471101  471101
#      3.0    257600  257600  257600  257600  257600  257600  257600  257600
# 17.0 1.0    826700  826700  826700  826700  826700  826700  826700  826700
#      2.0    506100  506100  506100  506100  506100  506100  506100  506100
#      3.0    260400  260400  260400  260400  260400  260400  260400  260400

# %%
# Extraer features y labels
X = df_chest_filt[['ACC_x', 'ACC_y', 'ACC_z', 'ECG', 'EMG', 'EDA', 'TEMP', 'RESP']].values
y = df_chest_filt['label'].values

# %%
y.dtype
# Out:
# dtype('float64')

# %%
# Primero se converte la columna de tipo int a tipo categórico
y = pd.Categorical(y)
y.dtype
# Out:
# CategoricalDtype(categories=[1.0, 2.0, 3.0], ordered=False)

# %% [markdown]
# # Clasificación binaria para los datos de pecho

# %%
# Crear un modelo CNN para clasificación binaria para los datos recopilados de pecho
sampling_rate = 700  # Hz
window_time = 5  # segundos
sequence_length = sampling_rate * window_time
step_size = sequence_length // 2

# Crear segmentos con overlapping windows
segments = []
labels = []
for i in range(0, len(X) - sequence_length, step_size):
    segment = X[i:i + sequence_length]
    label = y[i + sequence_length - 1]  
    segments.append(segment)
    labels.append(label)

# Convertir a vector 
X_segments = np.array(segments)
y_segments = np.array(labels)
# Clasificar label 1(fase neutral) y 3(diversión) a un grupo(no estrés) y label 2(estrés) a otro
y_segments_binary = np.where((y_segments == 1) | (y_segments == 3), 0, 1)

# Redimensionar X_segments para adaptar a la dimensión de entrada para LSTM
num_features = X_segments.shape[2]
X_segments_reshaped = X_segments.reshape((X_segments.shape[0], X_segments.shape[1], num_features))

# Definir el input layer para todos los sensores
input_layer = Input(shape=(sequence_length, num_features))

# Función para crear un bloque convolucional de 1D 
def conv_block(x, filters, kernel_size, stride, pool_size, pool_stride):
    x = Conv1D(filters=filters, kernel_size=kernel_size, strides=stride, activation='relu')(x)
    x = MaxPooling1D(pool_size=pool_size, strides=pool_stride)(x)
    return x

# Aplicar el bloque convolucional al input
output = conv_block(input_layer, filters=8, kernel_size=15, stride=2, pool_size=4, pool_stride=4)

# Conexión completa entre layers
x = Dense(32, activation='relu')(Flatten()(output))
x = Dense(16, activation='relu')(x)

# Output layer
output_layer = Dense(1, activation='sigmoid')(x)

# Generar el modelo
model_c_binary = Model(inputs=input_layer, outputs=output_layer)

# Imprimir por pantalla el resumen del modelo
model_c_binary.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3500, 8)]         0
#
#  conv1d (Conv1D)             (None, 1743, 8)           968
#
#  max_pooling1d (MaxPooling1  (None, 435, 8)            0
#  D)
#
#  flatten (Flatten)           (None, 3480)              0
#
#  dense (Dense)               (None, 32)                111392
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 112905 (441.04 KB)
# Trainable params: 112905 (441.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Normalización de datos
scaler = StandardScaler()
X_segments_normalized = scaler.fit_transform(X_segments_reshaped.reshape(-1, num_features)).reshape(X_segments_reshaped.shape)

# Dividir los datos para entrenamiento(80%) y para prueba(20%)
X_train, X_test, y_train, y_test = train_test_split(X_segments_normalized, y_segments_binary, test_size=0.2, random_state=42)

# Ejecutar el modelo
model_c_binary.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model_c_binary.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluar la precisión con los datos de prueba
loss, accuracy = model_c_binary.evaluate(X_test, y_test)
print(f'Precisión del modelo de clasificación binaria para datos de pecho: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/20
# 332/332 [==============================] - 7s 17ms/step - loss: 0.3267 - accuracy: 0.8287 - val_loss: 0.2140 - val_accuracy: 0.9069
# Epoch 2/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.1561 - accuracy: 0.9373 - val_loss: 0.1947 - val_accuracy: 0.9223
# Epoch 3/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.1295 - accuracy: 0.9491 - val_loss: 0.2896 - val_accuracy: 0.9114
# Epoch 4/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.1060 - accuracy: 0.9588 - val_loss: 0.1377 - val_accuracy: 0.9446
# Epoch 5/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0785 - accuracy: 0.9705 - val_loss: 0.1754 - val_accuracy: 0.9363
# Epoch 6/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0682 - accuracy: 0.9753 - val_loss: 0.1565 - val_accuracy: 0.9408
# Epoch 7/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0515 - accuracy: 0.9819 - val_loss: 0.1618 - val_accuracy: 0.9400
# Epoch 8/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0498 - accuracy: 0.9827 - val_loss: 0.1824 - val_accuracy: 0.9438
# Epoch 9/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0493 - accuracy: 0.9858 - val_loss: 0.2277 - val_accuracy: 0.9333
# Epoch 10/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0231 - accuracy: 0.9947 - val_loss: 0.2198 - val_accuracy: 0.9355
# Epoch 11/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0374 - accuracy: 0.9896 - val_loss: 0.2313 - val_accuracy: 0.9378
# Epoch 12/20
# 332/332 [==============================] - 5s 15ms/step - loss: 0.0220 - accuracy: 0.9943 - val_loss: 0.2487 - val_accuracy: 0.9404
# Epoch 13/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0176 - accuracy: 0.9955 - val_loss: 0.1901 - val_accuracy: 0.9517
# Epoch 14/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0200 - accuracy: 0.9957 - val_loss: 0.2171 - val_accuracy: 0.9427
# Epoch 15/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0304 - accuracy: 0.9910 - val_loss: 0.2155 - val_accuracy: 0.9510
# Epoch 16/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0288 - accuracy: 0.9915 - val_loss: 0.2278 - val_accuracy: 0.9472
# Epoch 17/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0155 - accuracy: 0.9963 - val_loss: 0.2166 - val_accuracy: 0.9525
# Epoch 18/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.1999 - val_accuracy: 0.9536
# Epoch 19/20
# 332/332 [==============================] - 5s 16ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.1938 - val_accuracy: 0.9559
# Epoch 20/20
# 332/332 [==============================] - 5s 16ms/step - loss: 7.1778e-04 - accuracy: 1.0000 - val_loss: 0.1965 - val_accuracy: 0.9574
# 83/83 [==============================] - 0s 6ms/step - loss: 0.1965 - accuracy: 0.9574
# Precisión del modelo de clasificación binaria para datos de pecho: 95.74%

# %%
y_pred_binary = (model_c_binary.predict(X_test) > 0.5).astype(int)
y_true_binary = y_test 
# Calcular F1-score, precisión y recall
f1 = f1_score(y_true_binary, y_pred_binary)
precision = precision_score(y_true_binary, y_pred_binary)
recall = recall_score(y_true_binary, y_pred_binary)

# Imprimir los reesultados
print("Resultados del modelo de clasificación binaria para datos de pecho: ")
print(f'F1-score: {f1:.4f}')
print(f'Precisión: {accuracy:.4f}')
print(f'Recall: {recall:.4f}') # Recall es la Tasa de verdaderos positivos

# Imprimir la matriz de confusión
conf_matrix = confusion_matrix(y_true_binary, y_pred_binary)
print('Matriz de confusión:')
print(conf_matrix)
# Out:
# 83/83 [==============================] - 1s 5ms/step
# Resultados del modelo de clasificación binaria para datos de pecho:
# F1-score: 0.9312
# Precisión: 0.9574
# Recall: 0.9295
# Matriz de confusión:
# [[1774   55]
#  [  58  765]]

# %%
# Mejorar el modelo modificando algunos parámetros
sampling_rate = 700  # Hz
window_time = 1  # segundos
sequence_length = sampling_rate * window_time
step_size = sequence_length // 2

segments = []
labels = []
for i in range(0, len(X) - sequence_length, step_size):
    segment = X[i:i + sequence_length]
    label = y[i + sequence_length - 1]  
    segments.append(segment)
    labels.append(label)

# Convertir a vector 
X_segments = np.array(segments)
y_segments = np.array(labels)
# Clasificar label 1(fase neutral) y 3(diversión) a un grupo(no estrés) y label 2(estrés) a otro
y_segments_binary = np.where((y_segments == 1) | (y_segments == 3), 0, 1)

# Redimensionar X_segments para adaptar a la dimensión de entrada para LSTM
num_features = X_segments.shape[2]
X_segments_reshaped = X_segments.reshape((X_segments.shape[0], X_segments.shape[1], num_features))

# Definir el input layer para todos los sensores
input_layer = Input(shape=(sequence_length, num_features))

# Función para crear un bloque convolucional de 1D 
def conv_block(x, filters, kernel_size, stride, pool_size, pool_stride):
    x = Conv1D(filters=filters, kernel_size=kernel_size, strides=stride, activation='relu')(x)
    x = MaxPooling1D(pool_size=pool_size, strides=pool_stride)(x)
    return x

# Aplicar el bloque convolucional al input
output = conv_block(input_layer, filters=8, kernel_size=15, stride=2, pool_size=4, pool_stride=4)

# Conexión completa entre layers
x = Dense(32, activation='relu')(Flatten()(output))
x = Dense(16, activation='relu')(x)

# Output layer
output_layer = Dense(1, activation='sigmoid')(x)

# Generar el modelo
model_c_binary_2 = Model(inputs=input_layer, outputs=output_layer)

# Imprimir por pantalla el resumen del modelo
model_c_binary_2.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 700, 8)]          0
#
#  conv1d_1 (Conv1D)           (None, 343, 8)            968
#
#  max_pooling1d_1 (MaxPoolin  (None, 85, 8)             0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 680)               0
#
#  dense_3 (Dense)             (None, 32)                21792
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23305 (91.04 KB)
# Trainable params: 23305 (91.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Normalización de datos
scaler = StandardScaler()
X_segments_normalized = scaler.fit_transform(X_segments_reshaped.reshape(-1, num_features)).reshape(X_segments_reshaped.shape)

# Dividir los datos para entrenamiento(80%) y para prueba(20%)
X_train, X_test, y_train, y_test = train_test_split(X_segments_normalized, y_segments_binary, test_size=0.2, random_state=42)

# Ejecutar el modelo con nuevo parámetro
model_c_binary_2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model_c_binary_2.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluar la precisión con los datos de prueba
loss, accuracy = model_c_binary_2.evaluate(X_test, y_test)
print(f'Precisión del modelo de clasificación binaria para datos de pecho: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/20
# 1658/1658 [==============================] - 13s 7ms/step - loss: 0.1750 - accuracy: 0.9220 - val_loss: 0.0863 - val_accuracy: 0.9694
# Epoch 2/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0669 - accuracy: 0.9778 - val_loss: 0.0511 - val_accuracy: 0.9820
# Epoch 3/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0454 - accuracy: 0.9855 - val_loss: 0.0507 - val_accuracy: 0.9836
# Epoch 4/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0347 - accuracy: 0.9896 - val_loss: 0.0644 - val_accuracy: 0.9808
# Epoch 5/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0330 - accuracy: 0.9896 - val_loss: 0.0386 - val_accuracy: 0.9891
# Epoch 6/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0284 - accuracy: 0.9910 - val_loss: 0.0446 - val_accuracy: 0.9863
# Epoch 7/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0232 - accuracy: 0.9927 - val_loss: 0.0274 - val_accuracy: 0.9931
# Epoch 8/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0234 - accuracy: 0.9933 - val_loss: 0.0386 - val_accuracy: 0.9893
# Epoch 9/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0198 - accuracy: 0.9942 - val_loss: 0.0326 - val_accuracy: 0.9919
# Epoch 10/20
# 1658/1658 [==============================] - 11s 6ms/step - loss: 0.0187 - accuracy: 0.9943 - val_loss: 0.0303 - val_accuracy: 0.9932
# Epoch 11/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0207 - accuracy: 0.9935 - val_loss: 0.0420 - val_accuracy: 0.9891
# Epoch 12/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.0335 - val_accuracy: 0.9926
# Epoch 13/20
# 1658/1658 [==============================] - 11s 6ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.0524 - val_accuracy: 0.9885
# Epoch 14/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0139 - accuracy: 0.9959 - val_loss: 0.0598 - val_accuracy: 0.9862
# Epoch 15/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0159 - accuracy: 0.9952 - val_loss: 0.0339 - val_accuracy: 0.9931
# Epoch 16/20
# 1658/1658 [==============================] - 11s 6ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.0326 - val_accuracy: 0.9943
# Epoch 17/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0140 - accuracy: 0.9962 - val_loss: 0.0498 - val_accuracy: 0.9903
# Epoch 18/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0155 - accuracy: 0.9956 - val_loss: 0.0388 - val_accuracy: 0.9906
# Epoch 19/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.0335 - val_accuracy: 0.9950
# Epoch 20/20
# 1658/1658 [==============================] - 11s 7ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0358 - val_accuracy: 0.9934
# 415/415 [==============================] - 1s 3ms/step - loss: 0.0358 - accuracy: 0.9934
# Precisión del modelo de clasificación binaria para datos de pecho: 99.34%

# %%
y_pred_binary = (model_c_binary_2.predict(X_test) > 0.5).astype(int)
y_true_binary = y_test 
# Calcular F1-score, precisión y recall
f1 = f1_score(y_true_binary, y_pred_binary)
precision = precision_score(y_true_binary, y_pred_binary)
recall = recall_score(y_true_binary, y_pred_binary)

# Imprimir los reesultados
print("Resultados del modelo de clasificación binaria para datos de pecho: ")
print(f'F1-score: {f1:.4f}')
print(f'Precisión: {accuracy:.4f}')
print(f'Recall: {recall:.4f}') # Recall es la Tasa de verdaderos positivos

# Imprimir la matriz de confusión
conf_matrix = confusion_matrix(y_true_binary, y_pred_binary)
print('Matriz de confusión:')
print(conf_matrix)
# Out:
# 415/415 [==============================] - 1s 3ms/step
# Resultados del modelo de clasificación binaria para datos de pecho:
# F1-score: 0.9893
# Precisión: 0.9934
# Recall: 0.9853
# Matriz de confusión:
# [[9162   27]
#  [  60 4012]]

# %% [markdown]
# Ha mejorado los resultados por disminuir el window_time a 1s, ahora se cambia otro parámetro para seguir mejorando los resultados.

# %%
# Mejorar el modelo modificando algunos parámetros
sampling_rate = 700  # Hz
window_time = 1  # segundos
sequence_length = sampling_rate * window_time
step_size = sequence_length // 2

segments = []
labels = []
for i in range(0, len(X) - sequence_length, step_size):
    segment = X[i:i + sequence_length]
    label = y[i + sequence_length - 1]  
    segments.append(segment)
    labels.append(label)

# Convertir a vector 
X_segments = np.array(segments)
y_segments = np.array(labels)

# Clasificar label 1(fase neutral) y 3(diversión) a un grupo(no estrés) y label 2(estrés) a otro
y_segments_binary = np.where((y_segments == 1) | (y_segments == 3), 0, 1)

# Redimensionar X_segments para adaptar a la dimensión de entrada para LSTM
num_features = X_segments.shape[2]
X_segments_reshaped = X_segments.reshape((X_segments.shape[0], X_segments.shape[1], num_features))

# Definir el input layer para todos los sensores
input_layer = Input(shape=(sequence_length, num_features))

# Función para crear un bloque convolucional de 1D 
def conv_block(x, filters, kernel_size, stride, pool_size, pool_stride):
    x = Conv1D(filters=filters, kernel_size=kernel_size, strides=stride, activation='relu')(x)
    x = MaxPooling1D(pool_size=pool_size, strides=pool_stride)(x)
    return x

# Aplicar el bloque convolucional al input
output = conv_block(input_layer, filters=16, kernel_size=15, stride=2, pool_size=4, pool_stride=4)

# Conexión completa entre layers
x = Dense(32, activation='relu')(Flatten()(output))
x = Dense(16, activation='relu')(x)

# Output layer
output_layer = Dense(1, activation='sigmoid')(x)

# Generar el modelo
model_c_binary_3 = Model(inputs=input_layer, outputs=output_layer)

# Imprimir por pantalla el resumen del modelo
model_c_binary_3.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 700, 8)]          0
#
#  conv1d_2 (Conv1D)           (None, 343, 16)           1936
#
#  max_pooling1d_2 (MaxPoolin  (None, 85, 16)            0
#  g1D)
#
#  flatten_2 (Flatten)         (None, 1360)              0
#
#  dense_6 (Dense)             (None, 32)                43552
#
#  dense_7 (Dense)             (None, 16)                528
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 46033 (179.82 KB)
# Trainable params: 46033 (179.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Normalización de datos
scaler = StandardScaler()
X_segments_normalized = scaler.fit_transform(X_segments_reshaped.reshape(-1, num_features)).reshape(X_segments_reshaped.shape)

# Dividir los datos para entrenamiento(80%) y para prueba(20%)
X_train, X_test, y_train, y_test = train_test_split(X_segments_normalized, y_segments_binary, test_size=0.2, random_state=42)

# Ejecutar el modelo con nuevos parámetros
model_c_binary_3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model_c_binary_3.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluar la precisión con los datos de prueba
loss, accuracy = model_c_binary_3.evaluate(X_test, y_test)
print(f'Precisión del modelo de clasificación binaria para datos de pecho: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/20
# 1658/1658 [==============================] - 14s 8ms/step - loss: 0.1420 - accuracy: 0.9421 - val_loss: 0.0705 - val_accuracy: 0.9796
# Epoch 2/20
# 1658/1658 [==============================] - 12s 7ms/step - loss: 0.0557 - accuracy: 0.9829 - val_loss: 0.0405 - val_accuracy: 0.9871
# Epoch 3/20
# 1658/1658 [==============================] - 14s 8ms/step - loss: 0.0410 - accuracy: 0.9877 - val_loss: 0.0375 - val_accuracy: 0.9902
# Epoch 4/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0330 - accuracy: 0.9901 - val_loss: 0.0342 - val_accuracy: 0.9912
# Epoch 5/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0288 - accuracy: 0.9914 - val_loss: 0.0451 - val_accuracy: 0.9870
# Epoch 6/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0216 - accuracy: 0.9935 - val_loss: 0.0333 - val_accuracy: 0.9908
# Epoch 7/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0228 - accuracy: 0.9931 - val_loss: 0.0473 - val_accuracy: 0.9864
# Epoch 8/20
# 1658/1658 [==============================] - 14s 9ms/step - loss: 0.0202 - accuracy: 0.9945 - val_loss: 0.0382 - val_accuracy: 0.9926
# Epoch 9/20
# 1658/1658 [==============================] - 14s 8ms/step - loss: 0.0189 - accuracy: 0.9949 - val_loss: 0.0442 - val_accuracy: 0.9890
# Epoch 10/20
# 1658/1658 [==============================] - 15s 9ms/step - loss: 0.0154 - accuracy: 0.9957 - val_loss: 0.0449 - val_accuracy: 0.9888
# Epoch 11/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0158 - accuracy: 0.9956 - val_loss: 0.0327 - val_accuracy: 0.9931
# Epoch 12/20
# 1658/1658 [==============================] - 14s 9ms/step - loss: 0.0140 - accuracy: 0.9963 - val_loss: 0.0389 - val_accuracy: 0.9922
# Epoch 13/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0157 - accuracy: 0.9959 - val_loss: 0.0314 - val_accuracy: 0.9937
# Epoch 14/20
# 1658/1658 [==============================] - 14s 8ms/step - loss: 0.0125 - accuracy: 0.9968 - val_loss: 0.0826 - val_accuracy: 0.9812
# Epoch 15/20
# 1658/1658 [==============================] - 12s 7ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 0.0303 - val_accuracy: 0.9922
# Epoch 16/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.0314 - val_accuracy: 0.9937
# Epoch 17/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0312 - val_accuracy: 0.9940
# Epoch 18/20
# 1658/1658 [==============================] - 12s 8ms/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0459 - val_accuracy: 0.9910
# Epoch 19/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.0469 - val_accuracy: 0.9907
# Epoch 20/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0336 - val_accuracy: 0.9942
# 415/415 [==============================] - 1s 4ms/step - loss: 0.0336 - accuracy: 0.9942
# Precisión del modelo de clasificación binaria para datos de pecho: 99.42%

# %%
y_pred_binary = (model_c_binary_3.predict(X_test) > 0.5).astype(int)
y_true_binary = y_test 
# Calcular F1-score, precisión y recall
f1 = f1_score(y_true_binary, y_pred_binary)
precision = precision_score(y_true_binary, y_pred_binary)
recall = recall_score(y_true_binary, y_pred_binary)

# Imprimir los reesultados
print("Resultados del modelo de clasificación binaria para datos de pecho: ")
print(f'F1-score: {f1:.4f}')
print(f'Precisión: {accuracy:.4f}')
print(f'Recall: {recall:.4f}') # Recall es la Tasa de verdaderos positivos

# Imprimir la matriz de confusión
conf_matrix = confusion_matrix(y_true_binary, y_pred_binary)
print('Matriz de confusión:')
print(conf_matrix)
# Out:
# 415/415 [==============================] - 1s 3ms/step
# Resultados del modelo de clasificación binaria para datos de pecho:
# F1-score: 0.9905
# Precisión: 0.9942
# Recall: 0.9889
# Matriz de confusión:
# [[9157   32]
#  [  45 4027]]

# %% [markdown]
# Ha mejorado todavía un poco los resultados al aumentar el número de filtros a 16, ahora modifica otro parámetro para intentar a seguir mejorando.

# %%
# Mejorar el modelo añadir 2 capas dropout
x = Dense(32, activation='relu')(Flatten()(output))
x = Dropout(0.5)(x)
x = Dense(16, activation='relu')(x)
x = Dropout(0.5)(x)

# Output layer
output_layer = Dense(1, activation='sigmoid')(x)

# Generar el modelo
model_c_binary_4 = Model(inputs=input_layer, outputs=output_layer)

# Imprimir por pantalla el resumen del modelo
model_c_binary_4.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 700, 8)]          0
#
#  conv1d_2 (Conv1D)           (None, 343, 16)           1936
#
#  max_pooling1d_2 (MaxPoolin  (None, 85, 16)            0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 1360)              0
#
#  dense_9 (Dense)             (None, 32)                43552
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_10 (Dense)            (None, 16)                528
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_11 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 46033 (179.82 KB)
# Trainable params: 46033 (179.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Ejecutar el modelo con nuevos parámetros
model_c_binary_4.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model_c_binary_4.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluar la precisión con los datos de prueba
loss, accuracy = model_c_binary_4.evaluate(X_test, y_test)
print(f'Precisión del modelo de clasificación binaria para datos de pecho: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/20
# 1658/1658 [==============================] - 15s 8ms/step - loss: 0.4023 - accuracy: 0.7544 - val_loss: 0.1861 - val_accuracy: 0.8743
# Epoch 2/20
# 1658/1658 [==============================] - 14s 9ms/step - loss: 0.2816 - accuracy: 0.8317 - val_loss: 0.1203 - val_accuracy: 0.9349
# Epoch 3/20
# 1658/1658 [==============================] - 14s 9ms/step - loss: 0.2384 - accuracy: 0.8674 - val_loss: 0.0856 - val_accuracy: 0.9577
# Epoch 4/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.2029 - accuracy: 0.8939 - val_loss: 0.0832 - val_accuracy: 0.9621
# Epoch 5/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.1798 - accuracy: 0.9189 - val_loss: 0.0790 - val_accuracy: 0.9605
# Epoch 6/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.1542 - accuracy: 0.9335 - val_loss: 0.0698 - val_accuracy: 0.9630
# Epoch 7/20
# 1658/1658 [==============================] - 12s 8ms/step - loss: 0.1372 - accuracy: 0.9412 - val_loss: 0.0614 - val_accuracy: 0.9657
# Epoch 8/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.1248 - accuracy: 0.9454 - val_loss: 0.0678 - val_accuracy: 0.9659
# Epoch 9/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.1221 - accuracy: 0.9468 - val_loss: 0.0684 - val_accuracy: 0.9634
# Epoch 10/20
# 1658/1658 [==============================] - 14s 8ms/step - loss: 0.1182 - accuracy: 0.9500 - val_loss: 0.0578 - val_accuracy: 0.9681
# Epoch 11/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.1137 - accuracy: 0.9508 - val_loss: 0.0662 - val_accuracy: 0.9667
# Epoch 12/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.1137 - accuracy: 0.9499 - val_loss: 0.0610 - val_accuracy: 0.9702
# Epoch 13/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.1014 - accuracy: 0.9515 - val_loss: 0.0653 - val_accuracy: 0.9654
# Epoch 14/20
# 1658/1658 [==============================] - 14s 8ms/step - loss: 0.0969 - accuracy: 0.9538 - val_loss: 0.0620 - val_accuracy: 0.9688
# Epoch 15/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0939 - accuracy: 0.9550 - val_loss: 0.0504 - val_accuracy: 0.9911
# Epoch 16/20
# 1658/1658 [==============================] - 14s 9ms/step - loss: 0.0910 - accuracy: 0.9567 - val_loss: 0.0680 - val_accuracy: 0.9660
# Epoch 17/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0853 - accuracy: 0.9586 - val_loss: 0.0601 - val_accuracy: 0.9722
# Epoch 18/20
# 1658/1658 [==============================] - 13s 8ms/step - loss: 0.0849 - accuracy: 0.9608 - val_loss: 0.0566 - val_accuracy: 0.9709
# Epoch 19/20
# 1658/1658 [==============================] - 15s 9ms/step - loss: 0.0814 - accuracy: 0.9628 - val_loss: 0.0585 - val_accuracy: 0.9692
# Epoch 20/20
# 1658/1658 [==============================] - 14s 8ms/step - loss: 0.0781 - accuracy: 0.9620 - val_loss: 0.0505 - val_accuracy: 0.9714
# 415/415 [==============================] - 1s 3ms/step - loss: 0.0505 - accuracy: 0.9714
# Precisión del modelo de clasificación binaria para datos de pecho: 97.14%

# %% [markdown]
# Ha empeorando por añadir 2 capas dropout, esto modelo se tiene que descartar y volver a coger el modelo model_c_binary_3 para más modificaciones.

# %%
# Mejorar el modelo añadiendo otra capa de output
output = conv_block(input_layer, filters=16, kernel_size=15, stride=2, pool_size=4, pool_stride=4)
output = conv_block(output, filters=32, kernel_size=10, stride=1, pool_size=2, pool_stride=2)

# Conexión completa entre layers
x = Dense(32, activation='relu')(Flatten()(output))
x = Dense(16, activation='relu')(x)

# Output layer
output_layer = Dense(1, activation='sigmoid')(x)

# Generar el modelo
model_c_binary_5 = Model(inputs=input_layer, outputs=output_layer)

# Imprimir por pantalla el resumen del modelo
model_c_binary_5.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 700, 8)]          0
#
#  conv1d_3 (Conv1D)           (None, 343, 16)           1936
#
#  max_pooling1d_3 (MaxPoolin  (None, 85, 16)            0
#  g1D)
#
#  conv1d_4 (Conv1D)           (None, 76, 32)            5152
#
#  max_pooling1d_4 (MaxPoolin  (None, 38, 32)            0
#  g1D)
#
#  flatten_4 (Flatten)         (None, 1216)              0
#
#  dense_12 (Dense)            (None, 32)                38944
#
#  dense_13 (Dense)            (None, 16)                528
#
#  dense_14 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 46577 (181.94 KB)
# Trainable params: 46577 (181.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Ejecutar el modelo con nuevos parámetros
model_c_binary_5.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model_c_binary_5.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluar la precisión con los datos de prueba
loss, accuracy = model_c_binary_5.evaluate(X_test, y_test)
print(f'Precisión del modelo de clasificación binaria para datos de pecho: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/20
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.1152 - accuracy: 0.9539 - val_loss: 0.0523 - val_accuracy: 0.9839
# Epoch 2/20
# 1658/1658 [==============================] - 16s 10ms/step - loss: 0.0385 - accuracy: 0.9881 - val_loss: 0.0435 - val_accuracy: 0.9885
# Epoch 3/20
# 1658/1658 [==============================] - 16s 9ms/step - loss: 0.0294 - accuracy: 0.9909 - val_loss: 0.0216 - val_accuracy: 0.9947
# Epoch 4/20
# 1658/1658 [==============================] - 16s 9ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.0207 - val_accuracy: 0.9949
# Epoch 5/20
# 1658/1658 [==============================] - 16s 10ms/step - loss: 0.0207 - accuracy: 0.9939 - val_loss: 0.0205 - val_accuracy: 0.9956
# Epoch 6/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0158 - accuracy: 0.9956 - val_loss: 0.0274 - val_accuracy: 0.9915
# Epoch 7/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0164 - accuracy: 0.9958 - val_loss: 0.0159 - val_accuracy: 0.9965
# Epoch 8/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0128 - accuracy: 0.9962 - val_loss: 0.0161 - val_accuracy: 0.9962
# Epoch 9/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0140 - accuracy: 0.9959 - val_loss: 0.0173 - val_accuracy: 0.9956
# Epoch 10/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0246 - val_accuracy: 0.9936
# Epoch 11/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0146 - val_accuracy: 0.9970
# Epoch 12/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.0471 - val_accuracy: 0.9875
# Epoch 13/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 0.0136 - val_accuracy: 0.9970
# Epoch 14/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0247 - val_accuracy: 0.9929
# Epoch 15/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.0222 - val_accuracy: 0.9944
# Epoch 16/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.0157 - val_accuracy: 0.9969
# Epoch 17/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0155 - val_accuracy: 0.9968
# Epoch 18/20
# 1658/1658 [==============================] - 17s 11ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0106 - val_accuracy: 0.9980
# Epoch 19/20
# 1658/1658 [==============================] - 17s 11ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.0165 - val_accuracy: 0.9970
# Epoch 20/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.0144 - val_accuracy: 0.9971
# 415/415 [==============================] - 2s 5ms/step - loss: 0.0144 - accuracy: 0.9971
# Precisión del modelo de clasificación binaria para datos de pecho: 99.71%

# %%
y_pred_binary = (model_c_binary_5.predict(X_test) > 0.5).astype(int)
y_true_binary = y_test 
# Calcular F1-score, precisión y recall
f1 = f1_score(y_true_binary, y_pred_binary)
precision = precision_score(y_true_binary, y_pred_binary)
recall = recall_score(y_true_binary, y_pred_binary)

# Imprimir los reesultados
print("Resultados del modelo de clasificación binaria para datos de pecho: ")
print(f'F1-score: {f1:.4f}')
print(f'Precisión: {accuracy:.4f}')
print(f'Recall: {recall:.4f}') # Recall es la Tasa de verdaderos positivos

# Imprimir la matriz de confusión
conf_matrix = confusion_matrix(y_true_binary, y_pred_binary)
print('Matriz de confusión:')
print(conf_matrix)
# Out:
# 415/415 [==============================] - 2s 4ms/step
# Resultados del modelo de clasificación binaria para datos de pecho:
# F1-score: 0.9952
# Precisión: 0.9971
# Recall: 0.9944
# Matriz de confusión:
# [[9173   16]
#  [  23 4049]]

# %% [markdown]
# Con otra capa de output ha mejorado los resultados, ahora se parte de este mismo modelo mode_c_binary_5 modificando otro parámetro learning rate a 0,01 para ver si se puede mejorar más.

# %%
# Modificar el modelo model_c_binary_5 con nuevo learning rate=0,01
optimizer = Adam(lr=0.01)
model_c_binary_5.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model_c_binary_5.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluar la precisión con los datos de prueba
loss, accuracy = model_c_binary_5.evaluate(X_test, y_test)
# Out:
# Epoch 1/20
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.0160 - val_accuracy: 0.9966
# Epoch 2/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0176 - val_accuracy: 0.9967
# Epoch 3/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0197 - val_accuracy: 0.9961
# Epoch 4/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0110 - val_accuracy: 0.9977
# Epoch 5/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0166 - val_accuracy: 0.9975
# Epoch 6/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0207 - val_accuracy: 0.9954
# Epoch 7/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0095 - val_accuracy: 0.9981
# Epoch 8/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0179 - val_accuracy: 0.9967
# Epoch 9/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0204 - val_accuracy: 0.9954
# Epoch 10/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0118 - val_accuracy: 0.9978
# Epoch 11/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0096 - val_accuracy: 0.9979
# Epoch 12/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0165 - val_accuracy: 0.9981
# Epoch 13/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0154 - val_accuracy: 0.9967
# Epoch 14/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.0126 - val_accuracy: 0.9975
# Epoch 15/20
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0163 - val_accuracy: 0.9973
# Epoch 16/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0147 - val_accuracy: 0.9967
# Epoch 17/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0174 - val_accuracy: 0.9970
# Epoch 18/20
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0207 - val_accuracy: 0.9966
# Epoch 19/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0272 - val_accuracy: 0.9946
# Epoch 20/20
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0141 - val_accuracy: 0.9974
# 415/415 [==============================] - 2s 4ms/step - loss: 0.0141 - accuracy: 0.9974

# %%
y_pred_binary = (model_c_binary_5.predict(X_test) > 0.5).astype(int)
y_true_binary = y_test 
# Calcular F1-score, precisión y recall
f1 = f1_score(y_true_binary, y_pred_binary)
precision = precision_score(y_true_binary, y_pred_binary)
recall = recall_score(y_true_binary, y_pred_binary)

# Imprimir los reesultados
print("Resultados del modelo de clasificación binaria para datos de pecho: ")
print(f'F1-score: {f1:.4f}')
print(f'Precisión: {accuracy:.4f}')
print(f'Recall: {recall:.4f}') # Recall es la Tasa de verdaderos positivos

# Imprimir la matriz de confusión
conf_matrix = confusion_matrix(y_true_binary, y_pred_binary)
print('Matriz de confusión:')
print(conf_matrix)
# Out:
# 415/415 [==============================] - 2s 4ms/step
# Resultados del modelo de clasificación binaria para datos de pecho:
# F1-score: 0.9957
# Precisión: 0.9974
# Recall: 0.9980
# Matriz de confusión:
# [[9162   27]
#  [   8 4064]]

# %% [markdown]
# Los resultados han mejorado un poco más cambiando el learning rate a 0,01, estos valores son bastantes buenos, ahora se prueba con más número de epochs para seguir mejorando.

# %%
# Ejecutar el modelo model_c_binary3 con número de epochs de 50
optimizer = Adam(lr=0.01)
model_c_binary_5.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model_c_binary_5.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_test, y_test))

# Evaluar la precisión con los datos de prueba
loss, accuracy = model_c_binary_5.evaluate(X_test, y_test)
print(f'Precisión del modelo de clasificación binaria para datos de pecho: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.0327 - val_accuracy: 0.9968
# Epoch 2/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0245 - val_accuracy: 0.9977
# Epoch 3/40
# 1658/1658 [==============================] - 17s 11ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0207 - val_accuracy: 0.9970
# Epoch 4/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 8.3912e-04 - accuracy: 0.9998 - val_loss: 0.0287 - val_accuracy: 0.9978
# Epoch 5/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 1.4270e-05 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9980
# Epoch 6/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 0.0225 - val_accuracy: 0.9973
# Epoch 7/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0243 - val_accuracy: 0.9978
# Epoch 8/40
# 1658/1658 [==============================] - 16s 10ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0205 - val_accuracy: 0.9979
# Epoch 9/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0306 - val_accuracy: 0.9962
# Epoch 10/40
# 1658/1658 [==============================] - 16s 10ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0261 - val_accuracy: 0.9977
# Epoch 11/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0205 - val_accuracy: 0.9974
# Epoch 12/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.0178 - val_accuracy: 0.9974
# Epoch 13/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0304 - val_accuracy: 0.9959
# Epoch 14/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0236 - val_accuracy: 0.9977
# Epoch 15/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 6.6510e-05 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9977
# Epoch 16/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 5.8455e-06 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9979
# Epoch 17/40
# 1658/1658 [==============================] - 17s 11ms/step - loss: 1.5449e-06 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 0.9977
# Epoch 18/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 6.2883e-07 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9978
# Epoch 19/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 2.5041e-07 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9978
# Epoch 20/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 1.0053e-07 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9979
# Epoch 21/40
# 1658/1658 [==============================] - 17s 11ms/step - loss: 3.9255e-08 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9978
# Epoch 22/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 1.5955e-08 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 0.9979
# Epoch 23/40
# 1658/1658 [==============================] - 17s 11ms/step - loss: 6.6353e-09 - accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 0.9979
# Epoch 24/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 2.8046e-09 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9980
# Epoch 25/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 1.2715e-09 - accuracy: 1.0000 - val_loss: 0.0519 - val_accuracy: 0.9980
# Epoch 26/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 5.6924e-10 - accuracy: 1.0000 - val_loss: 0.0545 - val_accuracy: 0.9980
# Epoch 27/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 2.3957e-10 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9980
# Epoch 28/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 1.2088e-10 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9980
# Epoch 29/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 5.6692e-11 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9981
# Epoch 30/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 3.0285e-11 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9981
# Epoch 31/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 1.7691e-11 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9981
# Epoch 32/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 1.3224e-11 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9981
# Epoch 33/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 9.8947e-12 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9981
# Epoch 34/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 8.0827e-12 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9981
# Epoch 35/40
# 1658/1658 [==============================] - 19s 12ms/step - loss: 6.3796e-12 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9981
# Epoch 36/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 6.0541e-12 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9981
# Epoch 37/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 6.2448e-12 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9981
# Epoch 38/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 6.4870e-12 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9981
# Epoch 39/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 6.6393e-12 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9980
# Epoch 40/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 6.7908e-12 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9980
# 415/415 [==============================] - 2s 5ms/step - loss: 0.0686 - accuracy: 0.9980
# Precisión del modelo de clasificación binaria para datos de pecho: 99.80%

# %%
y_pred_binary = (model_c_binary_5.predict(X_test) > 0.5).astype(int)
y_true_binary = y_test 
# Calcular F1-score, precisión y recall
f1 = f1_score(y_true_binary, y_pred_binary)
precision = precision_score(y_true_binary, y_pred_binary)
recall = recall_score(y_true_binary, y_pred_binary)

# Imprimir los reesultados
print("Resultados del modelo de clasificación binaria para datos de pecho: ")
print(f'F1-score: {f1:.4f}')
print(f'Precisión: {accuracy:.4f}')
print(f'Recall: {recall:.4f}') # Recall es la Tasa de verdaderos positivos

# Imprimir la matriz de confusión
conf_matrix = confusion_matrix(y_true_binary, y_pred_binary)
print('Matriz de confusión:')
print(conf_matrix)
# Out:
# 415/415 [==============================] - 2s 5ms/step
# Resultados del modelo de clasificación binaria para datos de pecho:
# F1-score: 0.9968
# Precisión: 0.9980
# Recall: 0.9971
# Matriz de confusión:
# [[9175   14]
#  [  12 4060]]

# %% [markdown]
# Han conseguido muy buenos resultados. Debido a la capacidad limitada de la memoria RAM, no se comprueba con más nº de epochs.

# %% [markdown]
# Los resultados son bastantes buenos, ya no tiene mucho sentido modificar más parámetros. Como resumen, los parámetros utilizados son:
#
# sampling rate: 700Hz
#
# window size: 1s
#
# sequence length: 700*1
#
# step size=sequence length//2
#
# nº de capas de output y los parámetros son:
# * capa 1 de output: = filters=16, kernel_size=15, stride=2, pool_size=4, pool_stride=4
# * capa 2 de output: filters=32, kernel_size=10, stride=1, pool_size=2, pool_stride=2
#
# optimizer: adam con learning rate=0,01
#
# nº epochs: 40

# %% [markdown]
# # Clasificación de tres estados afectivos para los datos de pecho

# %%
# Generar un modelo CNN para la clasificaión de tres estados para los datos de pecho
# Modificar el modelo anterior para adaptar a la nueva función
sampling_rate = 700  # Hz
window_time = 1  # segundos
sequence_length = sampling_rate * window_time
step_size = sequence_length // 2

segments = []
labels = []
for i in range(0, len(X) - sequence_length, step_size):
    segment = X[i:i + sequence_length]
    label = y[i + sequence_length - 1]  
    segments.append(segment)
    labels.append(label)

# Convertir a vector 
X_segments = np.array(segments)
y_segments = np.array(labels)

# Redimensionar X_segments para la entrada para LSTM
num_features = X_segments.shape[2]
X_segments_reshaped = X_segments.reshape((X_segments.shape[0], X_segments.shape[1], num_features))

# One hot encoding, num_classes = 3
y_segments = y_segments - 1
y_segments_one_hot = to_categorical(y_segments, num_classes=3) 

# Dividir datos para entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_segments_reshaped, y_segments_one_hot, test_size=0.2, random_state=42)

input_layer = Input(shape=(sequence_length, num_features))

def conv_block(x, filters, kernel_size, stride, pool_size, pool_stride):
    x = Conv1D(filters=filters, kernel_size=kernel_size, strides=stride, activation='relu')(x)
    x = MaxPooling1D(pool_size=pool_size, strides=pool_stride)(x)
    return x

# Aplicar el bloque convolucional al input
output = conv_block(input_layer, filters=16, kernel_size=15, stride=2, pool_size=4, pool_stride=4)
output = conv_block(output, filters=32, kernel_size=10, stride=1, pool_size=2, pool_stride=2)

# Conexión completa entre layers
x = Dense(32, activation='relu')(Flatten()(output))
x = Dense(16, activation='relu')(x)

# Output layer para 3 clases, donde 3 es el num_classes
output_layer = Dense(3, activation='softmax')(x)

# Generar el modelo para clasificación de 3 estados
model_c_three = Model(inputs=input_layer, outputs=output_layer)

model_c_three.summary()
optimizer = Adam(lr=0.01)
model_c_three.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model_c_three.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_test, y_test))

loss, accuracy = model_c_three.evaluate(X_test, y_test)
print(f'Precisión del modelo de clasificación de tres estados para datos de pecho: {accuracy * 100:.2f}%')
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 700, 8)]          0
#
#  conv1d_9 (Conv1D)           (None, 343, 16)           1936
#
#  max_pooling1d_9 (MaxPoolin  (None, 85, 16)            0
#  g1D)
#
#  conv1d_10 (Conv1D)          (None, 76, 32)            5152
#
#  max_pooling1d_10 (MaxPooli  (None, 38, 32)            0
#  ng1D)
#
#  flatten_7 (Flatten)         (None, 1216)              0
#
#  dense_21 (Dense)            (None, 32)                38944
#
#  dense_22 (Dense)            (None, 16)                528
#
#  dense_23 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 46611 (182.07 KB)
# Trainable params: 46611 (182.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.8287 - accuracy: 0.6208 - val_loss: 0.6846 - val_accuracy: 0.6970
# Epoch 2/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.5203 - accuracy: 0.7622 - val_loss: 0.5152 - val_accuracy: 0.7645
# Epoch 3/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.3962 - accuracy: 0.8167 - val_loss: 0.3355 - val_accuracy: 0.8453
# Epoch 4/40
# 1658/1658 [==============================] - 16s 10ms/step - loss: 0.3718 - accuracy: 0.8279 - val_loss: 0.2991 - val_accuracy: 0.8704
# Epoch 5/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.3291 - accuracy: 0.8520 - val_loss: 0.3161 - val_accuracy: 0.8619
# Epoch 6/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.3050 - accuracy: 0.8698 - val_loss: 0.2886 - val_accuracy: 0.8790
# Epoch 7/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.2561 - accuracy: 0.8978 - val_loss: 0.2167 - val_accuracy: 0.9149
# Epoch 8/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.2268 - accuracy: 0.9114 - val_loss: 0.2734 - val_accuracy: 0.8888
# Epoch 9/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.2145 - accuracy: 0.9188 - val_loss: 0.1583 - val_accuracy: 0.9448
# Epoch 10/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.1863 - accuracy: 0.9307 - val_loss: 0.2277 - val_accuracy: 0.9208
# Epoch 11/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.1780 - accuracy: 0.9345 - val_loss: 0.1395 - val_accuracy: 0.9483
# Epoch 12/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.1645 - accuracy: 0.9413 - val_loss: 0.1570 - val_accuracy: 0.9403
# Epoch 13/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.1622 - accuracy: 0.9427 - val_loss: 0.1708 - val_accuracy: 0.9361
# Epoch 14/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.1563 - accuracy: 0.9439 - val_loss: 0.1334 - val_accuracy: 0.9535
# Epoch 15/40
# 1658/1658 [==============================] - 20s 12ms/step - loss: 0.1510 - accuracy: 0.9449 - val_loss: 0.1654 - val_accuracy: 0.9420
# Epoch 16/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.1389 - accuracy: 0.9512 - val_loss: 0.1395 - val_accuracy: 0.9535
# Epoch 17/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.1324 - accuracy: 0.9537 - val_loss: 0.1405 - val_accuracy: 0.9510
# Epoch 18/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.1306 - accuracy: 0.9544 - val_loss: 0.1619 - val_accuracy: 0.9472
# Epoch 19/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.1246 - accuracy: 0.9564 - val_loss: 0.1659 - val_accuracy: 0.9374
# Epoch 20/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.1175 - accuracy: 0.9584 - val_loss: 0.1271 - val_accuracy: 0.9597
# Epoch 21/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.1136 - accuracy: 0.9610 - val_loss: 0.1158 - val_accuracy: 0.9603
# Epoch 22/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.1092 - accuracy: 0.9620 - val_loss: 0.1130 - val_accuracy: 0.9630
# Epoch 23/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0996 - accuracy: 0.9650 - val_loss: 0.0923 - val_accuracy: 0.9721
# Epoch 24/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0992 - accuracy: 0.9669 - val_loss: 0.0904 - val_accuracy: 0.9715
# Epoch 25/40
# 1658/1658 [==============================] - 16s 10ms/step - loss: 0.0999 - accuracy: 0.9662 - val_loss: 0.3932 - val_accuracy: 0.8865
# Epoch 26/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0913 - accuracy: 0.9692 - val_loss: 0.1580 - val_accuracy: 0.9437
# Epoch 27/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0834 - accuracy: 0.9719 - val_loss: 0.0863 - val_accuracy: 0.9759
# Epoch 28/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0924 - accuracy: 0.9684 - val_loss: 0.1163 - val_accuracy: 0.9616
# Epoch 29/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0929 - accuracy: 0.9701 - val_loss: 0.1287 - val_accuracy: 0.9581
# Epoch 30/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0789 - accuracy: 0.9739 - val_loss: 0.0854 - val_accuracy: 0.9692
# Epoch 31/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0741 - accuracy: 0.9749 - val_loss: 0.0936 - val_accuracy: 0.9698
# Epoch 32/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0817 - accuracy: 0.9732 - val_loss: 0.1276 - val_accuracy: 0.9588
# Epoch 33/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0797 - accuracy: 0.9736 - val_loss: 0.0946 - val_accuracy: 0.9715
# Epoch 34/40
# 1658/1658 [==============================] - 20s 12ms/step - loss: 0.0765 - accuracy: 0.9753 - val_loss: 0.1093 - val_accuracy: 0.9608
# Epoch 35/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0699 - accuracy: 0.9773 - val_loss: 0.0862 - val_accuracy: 0.9727
# Epoch 36/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0758 - accuracy: 0.9748 - val_loss: 0.1039 - val_accuracy: 0.9638
# Epoch 37/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0643 - accuracy: 0.9789 - val_loss: 0.0892 - val_accuracy: 0.9729
# Epoch 38/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0673 - accuracy: 0.9776 - val_loss: 0.0905 - val_accuracy: 0.9747
# Epoch 39/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0644 - accuracy: 0.9795 - val_loss: 0.0789 - val_accuracy: 0.9781
# Epoch 40/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0675 - accuracy: 0.9784 - val_loss: 0.0705 - val_accuracy: 0.9793
# 415/415 [==============================] - 2s 5ms/step - loss: 0.0705 - accuracy: 0.9793
# Precisión del modelo de clasificación de tres estados para datos de pecho: 97.93%

# %%
y_pred_three = np.argmax(model_c_three.predict(X_test), axis=1)
y_true_three = np.argmax(y_test, axis=1)

f1 = f1_score(y_true_three, y_pred_three, average='weighted')
precision = precision_score(y_true_three, y_pred_three, average='weighted')
recall = recall_score(y_true_three, y_pred_three, average='weighted')

# Imprimir los reesultados
print("Resultados del modelo de clasificación de tres estados para datos de pecho: ")
print(f'F1-score: {f1:.4f}')
print(f'Precisión: {accuracy:.4f}')
print(f'Recall: {recall:.4f}')

# Imprimir la matriz de confusión
conf_matrix = confusion_matrix(y_true_three, y_pred_three)
print('Matriz de confusión:')
print(conf_matrix)
# Out:
# 415/415 [==============================] - 2s 4ms/step
# Resultados del modelo de clasificación de tres estados para datos de pecho:
# F1-score: 0.9793
# Precisión: 0.9793
# Recall: 0.9793
# Matriz de confusión:
# [[6912   28   65]
#  [  16 4030   26]
#  [  69   70 2045]]

# %% [markdown]
# Intenta mejorar el resultado modificando algunos parámetros

# %%
optimizer = Adam(lr=0.001)
model_c_three.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model_c_three.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_test, y_test))

loss, accuracy = model_c_three.evaluate(X_test, y_test)
print(f'Precisión del modelo de clasificación de tres estados para datos de pecho: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.0562 - val_accuracy: 0.9868
# Epoch 2/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0433 - accuracy: 0.9863 - val_loss: 0.0621 - val_accuracy: 0.9825
# Epoch 3/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0388 - accuracy: 0.9872 - val_loss: 0.0593 - val_accuracy: 0.9854
# Epoch 4/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0373 - accuracy: 0.9885 - val_loss: 0.0684 - val_accuracy: 0.9859
# Epoch 5/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0389 - accuracy: 0.9879 - val_loss: 0.0620 - val_accuracy: 0.9848
# Epoch 6/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0398 - accuracy: 0.9867 - val_loss: 0.0545 - val_accuracy: 0.9877
# Epoch 7/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0392 - accuracy: 0.9877 - val_loss: 0.1197 - val_accuracy: 0.9704
# Epoch 8/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0344 - accuracy: 0.9893 - val_loss: 0.0641 - val_accuracy: 0.9832
# Epoch 9/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0358 - accuracy: 0.9886 - val_loss: 0.0979 - val_accuracy: 0.9752
# Epoch 10/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0343 - accuracy: 0.9890 - val_loss: 0.0639 - val_accuracy: 0.9865
# Epoch 11/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0374 - accuracy: 0.9883 - val_loss: 0.0695 - val_accuracy: 0.9842
# Epoch 12/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0352 - accuracy: 0.9885 - val_loss: 0.0679 - val_accuracy: 0.9850
# Epoch 13/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0353 - accuracy: 0.9893 - val_loss: 0.0746 - val_accuracy: 0.9826
# Epoch 14/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0344 - accuracy: 0.9900 - val_loss: 0.0842 - val_accuracy: 0.9799
# Epoch 15/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0339 - accuracy: 0.9893 - val_loss: 0.0983 - val_accuracy: 0.9739
# Epoch 16/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0331 - accuracy: 0.9898 - val_loss: 0.0752 - val_accuracy: 0.9805
# Epoch 17/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0342 - accuracy: 0.9893 - val_loss: 0.0878 - val_accuracy: 0.9814
# Epoch 18/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0326 - accuracy: 0.9903 - val_loss: 0.0877 - val_accuracy: 0.9799
# Epoch 19/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0355 - accuracy: 0.9887 - val_loss: 0.1212 - val_accuracy: 0.9697
# Epoch 20/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0315 - accuracy: 0.9901 - val_loss: 0.1090 - val_accuracy: 0.9747
# Epoch 21/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0308 - accuracy: 0.9905 - val_loss: 0.0850 - val_accuracy: 0.9825
# Epoch 22/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0320 - accuracy: 0.9904 - val_loss: 0.1211 - val_accuracy: 0.9698
# Epoch 23/40
# 1658/1658 [==============================] - 19s 11ms/step - loss: 0.0307 - accuracy: 0.9908 - val_loss: 0.0654 - val_accuracy: 0.9839
# Epoch 24/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0308 - accuracy: 0.9911 - val_loss: 0.0707 - val_accuracy: 0.9860
# Epoch 25/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0271 - accuracy: 0.9914 - val_loss: 0.0639 - val_accuracy: 0.9879
# Epoch 26/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0309 - accuracy: 0.9906 - val_loss: 0.0728 - val_accuracy: 0.9831
# Epoch 27/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0289 - accuracy: 0.9907 - val_loss: 0.0800 - val_accuracy: 0.9838
# Epoch 28/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0275 - accuracy: 0.9916 - val_loss: 0.0997 - val_accuracy: 0.9790
# Epoch 29/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0301 - accuracy: 0.9904 - val_loss: 0.0598 - val_accuracy: 0.9864
# Epoch 30/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0253 - accuracy: 0.9923 - val_loss: 0.0816 - val_accuracy: 0.9833
# Epoch 31/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0314 - accuracy: 0.9906 - val_loss: 0.0754 - val_accuracy: 0.9863
# Epoch 32/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0260 - accuracy: 0.9919 - val_loss: 0.0699 - val_accuracy: 0.9858
# Epoch 33/40
# 1658/1658 [==============================] - 17s 11ms/step - loss: 0.0309 - accuracy: 0.9909 - val_loss: 0.0819 - val_accuracy: 0.9830
# Epoch 34/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0283 - accuracy: 0.9918 - val_loss: 0.0698 - val_accuracy: 0.9848
# Epoch 35/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0297 - accuracy: 0.9912 - val_loss: 0.0745 - val_accuracy: 0.9845
# Epoch 36/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0254 - accuracy: 0.9922 - val_loss: 0.0732 - val_accuracy: 0.9861
# Epoch 37/40
# 1658/1658 [==============================] - 17s 10ms/step - loss: 0.0273 - accuracy: 0.9921 - val_loss: 0.0803 - val_accuracy: 0.9853
# Epoch 38/40
# 1658/1658 [==============================] - 17s 11ms/step - loss: 0.0312 - accuracy: 0.9907 - val_loss: 0.0793 - val_accuracy: 0.9814
# Epoch 39/40
# 1658/1658 [==============================] - 18s 11ms/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 0.1271 - val_accuracy: 0.9719
# Epoch 40/40
# 1658/1658 [==============================] - 17s 11ms/step - loss: 0.0259 - accuracy: 0.9924 - val_loss: 0.0791 - val_accuracy: 0.9860
# 415/415 [==============================] - 2s 5ms/step - loss: 0.0791 - accuracy: 0.9860
# Precisión del modelo de clasificación de tres estados para datos de pecho: 98.60%

# %%
y_pred_three = np.argmax(model_c_three.predict(X_test), axis=1)
y_true_three = np.argmax(y_test, axis=1)

f1 = f1_score(y_true_three, y_pred_three, average='weighted')
precision = precision_score(y_true_three, y_pred_three, average='weighted')
recall = recall_score(y_true_three, y_pred_three, average='weighted')

# Imprimir los reesultados
print("Resultados del modelo de clasificación de tres estados para datos de pecho: ")
print(f'F1-score: {f1:.4f}')
print(f'Precisión: {accuracy:.4f}')
print(f'Recall: {recall:.4f}')

# Imprimir la matriz de confusión
conf_matrix = confusion_matrix(y_true_three, y_pred_three)
print('Matriz de confusión:')
print(conf_matrix)
# Out:
# 415/415 [==============================] - 2s 4ms/step
# Resultados del modelo de clasificación de tres estados para datos de pecho:
# F1-score: 0.9861
# Precisión: 0.9860
# Recall: 0.9860
# Matriz de confusión:
# [[6965    7   33]
#  [  31 3989   52]
#  [  46   16 2122]]

# %% [markdown]
# Se ha mejorado con lr=0,001, ahora prueba con batch size=16 para ver si puede mejorar algo más.

# %%
optimizer = Adam(lr=0.001)
model_c_three.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model_c_three.fit(X_train, y_train, epochs=40, batch_size=16, validation_data=(X_test, y_test))

loss, accuracy = model_c_three.evaluate(X_test, y_test)
print(f'Precisión del modelo de clasificación de tres estados para datos de pecho: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0445 - accuracy: 0.9880 - val_loss: 0.0718 - val_accuracy: 0.9873
# Epoch 2/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0445 - accuracy: 0.9865 - val_loss: 0.0726 - val_accuracy: 0.9839
# Epoch 3/40
# 3316/3316 [==============================] - 26s 8ms/step - loss: 0.0487 - accuracy: 0.9859 - val_loss: 0.0615 - val_accuracy: 0.9879
# Epoch 4/40
# 3316/3316 [==============================] - 26s 8ms/step - loss: 0.0443 - accuracy: 0.9877 - val_loss: 0.0680 - val_accuracy: 0.9856
# Epoch 5/40
# 3316/3316 [==============================] - 26s 8ms/step - loss: 0.0431 - accuracy: 0.9870 - val_loss: 0.0952 - val_accuracy: 0.9791
# Epoch 6/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0443 - accuracy: 0.9869 - val_loss: 0.0774 - val_accuracy: 0.9816
# Epoch 7/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0406 - accuracy: 0.9886 - val_loss: 0.0718 - val_accuracy: 0.9844
# Epoch 8/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0433 - accuracy: 0.9880 - val_loss: 0.0740 - val_accuracy: 0.9853
# Epoch 9/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0431 - accuracy: 0.9872 - val_loss: 0.1588 - val_accuracy: 0.9631
# Epoch 10/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0411 - accuracy: 0.9887 - val_loss: 0.1420 - val_accuracy: 0.9630
# Epoch 11/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0417 - accuracy: 0.9872 - val_loss: 0.0775 - val_accuracy: 0.9857
# Epoch 12/40
# 3316/3316 [==============================] - 30s 9ms/step - loss: 0.0442 - accuracy: 0.9873 - val_loss: 0.1141 - val_accuracy: 0.9742
# Epoch 13/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0401 - accuracy: 0.9878 - val_loss: 0.1317 - val_accuracy: 0.9655
# Epoch 14/40
# 3316/3316 [==============================] - 29s 9ms/step - loss: 0.0384 - accuracy: 0.9887 - val_loss: 0.0870 - val_accuracy: 0.9827
# Epoch 15/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0434 - accuracy: 0.9874 - val_loss: 0.1210 - val_accuracy: 0.9750
# Epoch 16/40
# 3316/3316 [==============================] - 30s 9ms/step - loss: 0.0418 - accuracy: 0.9880 - val_loss: 0.0953 - val_accuracy: 0.9770
# Epoch 17/40
# 3316/3316 [==============================] - 32s 10ms/step - loss: 0.0393 - accuracy: 0.9883 - val_loss: 0.1112 - val_accuracy: 0.9755
# Epoch 18/40
# 3316/3316 [==============================] - 30s 9ms/step - loss: 0.0415 - accuracy: 0.9878 - val_loss: 0.0772 - val_accuracy: 0.9847
# Epoch 19/40
# 3316/3316 [==============================] - 30s 9ms/step - loss: 0.0392 - accuracy: 0.9888 - val_loss: 0.0783 - val_accuracy: 0.9846
# Epoch 20/40
# 3316/3316 [==============================] - 30s 9ms/step - loss: 0.0446 - accuracy: 0.9878 - val_loss: 0.0958 - val_accuracy: 0.9805
# Epoch 21/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0388 - accuracy: 0.9884 - val_loss: 0.0773 - val_accuracy: 0.9854
# Epoch 22/40
# 3316/3316 [==============================] - 30s 9ms/step - loss: 0.0381 - accuracy: 0.9889 - val_loss: 0.0701 - val_accuracy: 0.9867
# Epoch 23/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0402 - accuracy: 0.9887 - val_loss: 0.0947 - val_accuracy: 0.9803
# Epoch 24/40
# 3316/3316 [==============================] - 29s 9ms/step - loss: 0.0455 - accuracy: 0.9876 - val_loss: 0.0792 - val_accuracy: 0.9785
# Epoch 25/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0366 - accuracy: 0.9897 - val_loss: 0.0931 - val_accuracy: 0.9811
# Epoch 26/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0395 - accuracy: 0.9883 - val_loss: 0.0853 - val_accuracy: 0.9821
# Epoch 27/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0376 - accuracy: 0.9893 - val_loss: 0.0775 - val_accuracy: 0.9859
# Epoch 28/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0381 - accuracy: 0.9889 - val_loss: 0.1564 - val_accuracy: 0.9653
# Epoch 29/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0393 - accuracy: 0.9898 - val_loss: 0.0946 - val_accuracy: 0.9796
# Epoch 30/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0367 - accuracy: 0.9900 - val_loss: 0.1123 - val_accuracy: 0.9780
# Epoch 31/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0404 - accuracy: 0.9888 - val_loss: 0.0839 - val_accuracy: 0.9843
# Epoch 32/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0392 - accuracy: 0.9894 - val_loss: 0.0714 - val_accuracy: 0.9867
# Epoch 33/40
# 3316/3316 [==============================] - 30s 9ms/step - loss: 0.0335 - accuracy: 0.9903 - val_loss: 0.1230 - val_accuracy: 0.9735
# Epoch 34/40
# 3316/3316 [==============================] - 28s 8ms/step - loss: 0.0405 - accuracy: 0.9887 - val_loss: 0.1510 - val_accuracy: 0.9685
# Epoch 35/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0365 - accuracy: 0.9897 - val_loss: 0.1796 - val_accuracy: 0.9643
# Epoch 36/40
# 3316/3316 [==============================] - 30s 9ms/step - loss: 0.0371 - accuracy: 0.9895 - val_loss: 0.1075 - val_accuracy: 0.9830
# Epoch 37/40
# 3316/3316 [==============================] - 26s 8ms/step - loss: 0.0380 - accuracy: 0.9900 - val_loss: 0.1095 - val_accuracy: 0.9759
# Epoch 38/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0432 - accuracy: 0.9882 - val_loss: 0.0874 - val_accuracy: 0.9817
# Epoch 39/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0309 - accuracy: 0.9910 - val_loss: 0.1164 - val_accuracy: 0.9748
# Epoch 40/40
# 3316/3316 [==============================] - 27s 8ms/step - loss: 0.0368 - accuracy: 0.9899 - val_loss: 0.1028 - val_accuracy: 0.9818
# 415/415 [==============================] - 2s 5ms/step - loss: 0.1028 - accuracy: 0.9818
# Precisión del modelo de clasificación de tres estados para datos de pecho: 98.18%

# %%
y_pred_three = np.argmax(model_c_three.predict(X_test), axis=1)
y_true_three = np.argmax(y_test, axis=1)

f1 = f1_score(y_true_three, y_pred_three, average='weighted')
precision = precision_score(y_true_three, y_pred_three, average='weighted')
recall = recall_score(y_true_three, y_pred_three, average='weighted')

# Imprimir los reesultados
print("Resultados del modelo de clasificación de tres estados para datos de pecho: ")
print(f'F1-score: {f1:.4f}')
print(f'Precisión: {accuracy:.4f}')
print(f'Recall: {recall:.4f}')

# Imprimir la matriz de confusión
conf_matrix = confusion_matrix(y_true_three, y_pred_three)
print('Matriz de confusión:')
print(conf_matrix)
# Out:
# 415/415 [==============================] - 2s 5ms/step
# Resultados del modelo de clasificación de tres estados para datos de pecho:
# F1-score: 0.9818
# Precisión: 0.9818
# Recall: 0.9818
# Matriz de confusión:
# [[6906   19   80]
#  [  33 4007   32]
#  [  19   59 2106]]

# %% [markdown]
# Los resultados han empeorado comparando con el anterior, pero hay que tener en cuenta que esa precisión que consigue es bastante alta, es normal que no puede alcanzar más. Por lo tanto, se queda con los resultados del modelo anterior, es decir, con una precisión de 98,60%.
